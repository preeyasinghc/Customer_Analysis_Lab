# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('file1.csv')

# %%
df2 = pd.read_csv('file2.csv')

# %%
df3 = pd.read_csv('file3.csv')

# %%
df1
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                      88                    1/0/00          633.600000
# 1                     114                    1/0/00          547.200000
# 2                     112                    1/0/00          537.600000
# 3                     214                    1/1/00         1027.200000
# 4                      94                    1/0/00          451.200000
# ..                    ...                       ...                 ...
# 991                    70                    1/0/00          185.667213
# 992                    68                    1/0/00          140.747286
# 993                    70                    1/0/00          471.050488
# 994                    96                    1/0/00           28.460568
# 995                   111                    1/0/00          700.349052
#
#         Policy Type  Vehicle Class
# 0     Personal Auto  Four-Door Car
# 1      Special Auto            SUV
# 2     Personal Auto   Two-Door Car
# 3     Personal Auto     Luxury Car
# 4    Corporate Auto   Two-Door Car
# ..              ...            ...
# 991   Personal Auto  Four-Door Car
# 992  Corporate Auto  Four-Door Car
# 993  Corporate Auto   Two-Door Car
# 994   Personal Auto   Two-Door Car
# 995   Personal Auto            SUV
#
# [996 rows x 11 columns]

# %%
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                      88                    1/0/00          633.600000
# 1                     114                    1/0/00          547.200000
# 2                     112                    1/0/00          537.600000
# 3                     214                    1/1/00         1027.200000
# 4                      94                    1/0/00          451.200000
# ..                    ...                       ...                 ...
# 991                    70                    1/0/00          185.667213
# 992                    68                    1/0/00          140.747286
# 993                    70                    1/0/00          471.050488
# 994                    96                    1/0/00           28.460568
# 995                   111                    1/0/00          700.349052
#
#         Policy Type  Vehicle Class
# 0     Personal Auto  Four-Door Car
# 1      Special Auto            SUV
# 2     Personal Auto   Two-Door Car
# 3     Personal Auto     Luxury Car
# 4    Corporate Auto   Two-Door Car
# ..              ...            ...
# 991   Personal Auto  Four-Door Car
# 992  Corporate Auto  Four-Door Car
# 993  Corporate Auto   Two-Door Car
# 994   Personal Auto   Two-Door Car
# 995   Personal Auto            SUV
#
# [996 rows x 11 columns]

# %%
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# 0         M       0                   104                          0
# 1         M       0                    66                          0
# 2         F   25820                    82                          0
# 3         F       0                   121                          0
# 4         M   30366                   101                          2
# ...     ...     ...                   ...                        ...
# 7065      M   71941                    73                          0
# 7066      F   21604                    79                          0
# 7067      M       0                    85                          3
# 7068      M   21941                    96                          0
# 7069      M       0                    77                          0
#
#          Policy Type  Total Claim Amount  Vehicle Class
# 0      Personal Auto          499.200000   Two-Door Car
# 1      Personal Auto            3.468912   Two-Door Car
# 2      Personal Auto          393.600000  Four-Door Car
# 3      Personal Auto          699.615192            SUV
# 4      Personal Auto          484.800000            SUV
# ...              ...                 ...            ...
# 7065   Personal Auto          198.234764  Four-Door Car
# 7066  Corporate Auto          379.200000  Four-Door Car
# 7067  Corporate Auto          790.784983  Four-Door Car
# 7068   Personal Auto          691.200000  Four-Door Car
# 7069  Corporate Auto          369.600000   Two-Door Car
#
# [7070 rows x 11 columns]

# %%
##Show the DataFrame's shape.##

# %%
shape = df1.shape
print('\nDataFrame Shape:', shape)
# Out:
# DataFrame Shape: (996, 11)

# %%
###Standardize header names.##

# %%
df1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=996, step=1)

# %%
##Rearrange the columns in the dataframe as needed##

# %%
new_columns = ['Customer','Gender','State','Education','Income','Customer Lifetime Value', 
        'Monthly Premium Auto', 'Number of Open Complaints',
       'Policy Type', 'Total Claim Amount', 'Vehicle Class']
df3 = df3[new_columns]

# %%
df3
# Out:
#      Customer Gender       State             Education  Income  \
# 0     SA25987      M  Washington  High School or Below       0
# 1     TB86706      M     Arizona                Master       0
# 2     ZL73902      F      Nevada              Bachelor   25820
# 3     KX23516      F  California  High School or Below       0
# 4     FN77294      M  California  High School or Below   30366
# ...       ...    ...         ...                   ...     ...
# 7065  LA72316      M  California              Bachelor   71941
# 7066  PK87824      F  California               College   21604
# 7067  TD14365      M  California              Bachelor       0
# 7068  UP19263      M  California               College   21941
# 7069  Y167826      M  California               College       0
#
#       Customer Lifetime Value  Monthly Premium Auto  \
# 0                 3479.137523                   104
# 1                 2502.637401                    66
# 2                 3265.156348                    82
# 3                 4455.843406                   121
# 4                 7704.958480                   101
# ...                       ...                   ...
# 7065             23405.987980                    73
# 7066              3096.511217                    79
# 7067              8163.890428                    85
# 7068              7524.442436                    96
# 7069              2611.836866                    77
#
#       Number of Open Complaints     Policy Type  Total Claim Amount  \
# 0                             0   Personal Auto          499.200000
# 1                             0   Personal Auto            3.468912
# 2                             0   Personal Auto          393.600000
# 3                             0   Personal Auto          699.615192
# 4                             2   Personal Auto          484.800000
# ...                         ...             ...                 ...
# 7065                          0   Personal Auto          198.234764
# 7066                          0  Corporate Auto          379.200000
# 7067                          3  Corporate Auto          790.784983
# 7068                          0   Personal Auto          691.200000
# 7069                          0  Corporate Auto          369.600000
#
#       Vehicle Class
# 0      Two-Door Car
# 1      Two-Door Car
# 2     Four-Door Car
# 3               SUV
# 4               SUV
# ...             ...
# 7065  Four-Door Car
# 7066  Four-Door Car
# 7067  Four-Door Car
# 7068  Four-Door Car
# 7069   Two-Door Car
#
# [7070 rows x 11 columns]

# %%
##Concatenate the three dataframes##

# %%
data = pd.concat([df1, df2, df3])
data.tail(15)
# Out:
#      Customer Customer Lifetime Value             Education GENDER  Income  \
# 7055  YX35990             5479.555081                Master    NaN   56005
# 7056  RN61682             2114.738469              Bachelor    NaN       0
# 7057  BB10681             4140.648654               College    NaN       0
# 7058  FH43628             25464.82059               College    NaN   13663
# 7059  WZ45103             5678.050167              Bachelor    NaN       0
# 7060  CB59349              16261.5855                Master    NaN   60646
# 7061  RX91025               19872.262  High School or Below    NaN       0
# 7062  AC13887             4628.995325              Bachelor    NaN       0
# 7063  TF56202             5032.165498               College    NaN   66367
# 7064  YM19146             4100.398533               College    NaN   47761
# 7065  LA72316             23405.98798              Bachelor    NaN   71941
# 7066  PK87824             3096.511217               College    NaN   21604
# 7067  TD14365             8163.890428              Bachelor    NaN       0
# 7068  UP19263             7524.442436               College    NaN   21941
# 7069  Y167826             2611.836866               College    NaN       0
#
#       Monthly Premium Auto Number of Open Complaints     Policy Type   ST  \
# 7055                    68                         1  Corporate Auto  NaN
# 7056                    72                         5   Personal Auto  NaN
# 7057                   123                         2  Corporate Auto  NaN
# 7058                    97                         0   Personal Auto  NaN
# 7059                    76                         0   Personal Auto  NaN
# 7060                   134                         0   Personal Auto  NaN
# 7061                   185                         0   Personal Auto  NaN
# 7062                    67                         0  Corporate Auto  NaN
# 7063                    64                         0   Personal Auto  NaN
# 7064                   104                         0   Personal Auto  NaN
# 7065                    73                         0   Personal Auto  NaN
# 7066                    79                         0  Corporate Auto  NaN
# 7067                    85                         3  Corporate Auto  NaN
# 7068                    96                         0   Personal Auto  NaN
# 7069                    77                         0  Corporate Auto  NaN
#
#       Total Claim Amount  Vehicle Class Gender       State
# 7055          326.400000  Four-Door Car      M  California
# 7056          518.400000  Four-Door Car      F  California
# 7057          590.400000            SUV      F  California
# 7058          465.600000  Four-Door Car      F  California
# 7059          364.800000  Four-Door Car      F  California
# 7060          643.200000            SUV      M  California
# 7061         1950.725547            SUV      M  California
# 7062          482.400000   Two-Door Car      M  California
# 7063          307.200000   Two-Door Car      M  California
# 7064          541.282007  Four-Door Car      F  California
# 7065          198.234764  Four-Door Car      M  California
# 7066          379.200000  Four-Door Car      F  California
# 7067          790.784983  Four-Door Car      M  California
# 7068          691.200000  Four-Door Car      M  California
# 7069          369.600000   Two-Door Car      M  California

# %%
data = pd.concat([df1, df2, df3])
data.head(15)
# Out:
#    Customer Customer Lifetime Value             Education GENDER  Income  \
# 0   GS98873              323912.47%              Bachelor      F   16061
# 1   CW49887              462680.11%                Master      F   79487
# 2   MY31220              899704.02%               College      F   54230
# 3   UH35128             2580706.30%               College      F   71210
# 4   WH52799              380812.21%               College      F   94903
# 5   WL99637              761413.80%              Bachelor      M   27293
# 6   UC84059              689845.53%                Master      F   70950
# 7   HW62747              229837.92%               College      M       0
# 8   BH11344              280669.61%                Doctor      F   37009
# 9   TX28465              520611.82%               College      M   52629
# 10  OK56965             4570865.34%              Bachelor      F   31264
# 11  WT22392              800734.91%               College      F   65473
# 12  PH85036              548254.94%             Bachelors      F   79325
# 13  KC71643              246323.68%  High School or Below      M   99144
# 14  NR32615              549894.07%               College      M   22520
#
#     Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                     88                    1/0/00   Personal Auto
# 1                    114                    1/0/00    Special Auto
# 2                    112                    1/0/00   Personal Auto
# 3                    214                    1/1/00   Personal Auto
# 4                     94                    1/0/00  Corporate Auto
# 5                     96                    1/0/00   Personal Auto
# 6                    171                    1/0/00   Personal Auto
# 7                     63                    1/0/00  Corporate Auto
# 8                     71                    1/0/00  Corporate Auto
# 9                     65                    1/0/00   Personal Auto
# 10                   198                    1/1/00   Personal Auto
# 11                    67                    1/0/00   Personal Auto
# 12                    68                    1/0/00  Corporate Auto
# 13                    61                    1/0/00  Corporate Auto
# 14                    73                    1/0/00  Corporate Auto
#
#             ST  Total Claim Amount  Vehicle Class Gender State
# 0      Arizona          633.600000  Four-Door Car    NaN   NaN
# 1   California          547.200000            SUV    NaN   NaN
# 2   California          537.600000   Two-Door Car    NaN   NaN
# 3       Oregon         1027.200000     Luxury Car    NaN   NaN
# 4      Arizona          451.200000   Two-Door Car    NaN   NaN
# 5      Arizona          469.030907   Two-Door Car    NaN   NaN
# 6   California          565.929394     Sports Car    NaN   NaN
# 7       Oregon          302.400000  Four-Door Car    NaN   NaN
# 8       Oregon          145.673348   Two-Door Car    NaN   NaN
# 9       Nevada          136.684141  Four-Door Car    NaN   NaN
# 10  California          825.657746     Luxury SUV    NaN   NaN
# 11      Oregon          277.685667  Four-Door Car    NaN   NaN
# 12  Washington          251.294821  Four-Door Car    NaN   NaN
# 13      Oregon          292.800000  Four-Door Car    NaN   NaN
# 14  California          350.400000  Four-Door Car    NaN   NaN

# %%
##Which columns are numerical?##

# %%
df1.describe()
# Out:
#              Income  Monthly Premium Auto  Total Claim Amount
# count    996.000000            996.000000          996.000000
# mean   39764.920683            143.347390          417.609099
# std    30203.714667            572.289901          271.928647
# min        0.000000             61.000000            1.687291
# 25%    16505.500000             68.000000          278.794307
# 50%    36533.000000             80.000000          350.400000
# 75%    63540.000000            107.000000          513.339366
# max    99981.000000           7575.000000         2201.327879

# %%
##Which columns are categorical?##

# %%
df1.dtypes
# Out:
# Customer                      object
# Customer Lifetime Value       object
# Education                     object
# GENDER                        object
# Income                         int64
# Monthly Premium Auto           int64
# Number of Open Complaints     object
# Policy Type                   object
# ST                            object
# Total Claim Amount           float64
# Vehicle Class                 object
# dtype: object

# %%
##Understand the meaning of all columns##

# %%
##Perform the data cleaning operations mentioned so far in class##

Delete the column education and the number of open complaints from the dataframe.
Correct the values in the column customer lifetime value. They are given as a percent, 
so multiply them by 100 and change dtype to numerical type.
Check for duplicate rows in the data and remove if any.
Filter out the data for customers who have an income of 0 or less.

# %%
df1.drop(['Education','Number of Open Complaints'], axis=1)
df1.columns
# Out:
# Index(['Customer', 'Customer Lifetime Value', 'Education', 'GENDER', 'Income',
#        'Monthly Premium Auto', 'Number of Open Complaints', 'Policy Type',
#        'ST', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
df1.duplicated
# Out:
# <bound method DataFrame.duplicated of     Customer Customer Lifetime Value Education GENDER  Income  \
# 0    GS98873              323912.47%  Bachelor      F   16061
# 1    CW49887              462680.11%    Master      F   79487
# 2    MY31220              899704.02%   College      F   54230
# 3    UH35128             2580706.30%   College      F   71210
# 4    WH52799              380812.21%   College      F   94903
# ..       ...                     ...       ...    ...     ...
# 991  HV85198              847141.75%    Master      M   63513
# 992  BS91566              543121.91%   College      F   58161
# 993  IL40123              568964.41%   College      F   83640
# 994  MY32149              368672.38%    Master      F       0
# 995  SA91515              399258.39%  Bachelor      M       0
#
#      Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                      88                    1/0/00   Personal Auto
# 1                     114                    1/0/00    Special Auto
# 2                     112                    1/0/00   Personal Auto
# 3                     214                    1/1/00   Personal Auto
# 4                      94                    1/0/00  Corporate Auto
# ..                    ...                       ...             ...
# 991                    70                    1/0/00   Personal Auto
# 992                    68                    1/0/00  Corporate Auto
# 993                    70                    1/0/00  Corporate Auto
# 994                    96                    1/0/00   Personal Auto
# 995                   111                    1/0/00   Personal Auto
#
#              ST  Total Claim Amount  Vehicle Class
# 0       Arizona          633.600000  Four-Door Car
# 1    California          547.200000            SUV
# 2    California          537.600000   Two-Door Car
# 3        Oregon         1027.200000     Luxury Car
# 4       Arizona          451.200000   Two-Door Car
# ..          ...                 ...            ...
# 991     Arizona          185.667213  Four-Door Car
# 992     Arizona          140.747286  Four-Door Car
# 993      Nevada          471.050488   Two-Door Car
# 994  California           28.460568   Two-Door Car
# 995  California          700.349052            SUV
#
# [996 rows x 11 columns]>

# %%
##Correct the values in the column customer lifetime value. They are given as a percent, 
so multiply them by 100 and change dtype to numerical type.##
# Out:
#   File "/var/folders/rg/9mqy0ndj26v32y8v4h0_16h80000gn/T/ipykernel_7204/4103425372.py", line 2
#     so multiply them by 100 and change dtype to numerical type.##
#        ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('file1.csv')

# %%
df1['Customer Lifetime Value'] = df1['Customer Lifetime Value'].str.replace(r'%', '')

# %%
df1['Customer Lifetime Value'] = df1['Customer Lifetime Value'].astype(float) # converts the strings into floats

# %%
df1['Customer Lifetime Value'] = round(df1['Customer Lifetime Value'],0)

# %%
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#       Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                         NaN      0.0                1000.0
# 1                    697954.0      0.0                  94.0
# 2                   1288743.0  48767.0                 108.0
# 3                    764586.0      0.0                 106.0
# 4                    536308.0  36357.0                  68.0
# ...                       ...      ...                   ...
# 4003                      NaN      NaN                   NaN
# 4004                      NaN      NaN                   NaN
# 4005                      NaN      NaN                   NaN
# 4006                      NaN      NaN                   NaN
# 4007                      NaN      NaN                   NaN
#
#      Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [4008 rows x 11 columns]

# %%
df1['Customer Lifetime Value']  = df1['Customer Lifetime Value'] *100
df1.head()
# Out:
#   Customer          ST GENDER             Education  Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                      NaN
# 1  QZ44356     Arizona      F              Bachelor             6.979540e+09
# 2  AI49188      Nevada      F              Bachelor             1.288743e+10
# 3  WW63253  California      M              Bachelor             7.645860e+09
# 4  GA49547  Washington      M  High School or Below             5.363080e+09
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935
# 2   Two-Door Car          566.472247
# 3            SUV          529.881344
# 4  Four-Door Car           17.269323

# %%
##Filter out the data for customers who have an income of 0 or less.##

# %%
df1['Income'] =df1[df1['Income'] > 0]['Income'] #drop values lower than 0

# %% [markdown]
# df1['income'] = df1[df1'income'] > 0]['income']
# print("Count of clients with an income less than 1 = ",
#      df1[df1['income'] < 1]['income'].count())

# %%
print("Count of clients with an income less than 1 = ",
     df1[df1['Income'] < 1]['Income'].count())
# Out:
# Count of clients with an income less than 1 =  0
